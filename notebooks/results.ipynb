# %% [markdown]
# # Results

# %%
from handwriting_gen.plotting import plot_stroke
from handwriting_gen.models import generate_unconditionally, generate_conditionally

# %% [markdown]
# Please, don't modify anything below.
#
# ### Unconditional generation:

# %%
stroke = generate_unconditionally(random_seed=5)
plot_stroke(stroke)
# Out:
# Loading:  {'save_path': '/home/trex/handwriting-generation/models/unconditional-stroke-model', 'learning_rate': 0.0001, 'mixture_components': 20, 'num_layers': 3, 'hidden_size': 200, 'dropout': 0.0, 'max_grad_norm': 5, 'decay': 0.95, 'momentum': 0.9, 'rnn_steps': 1, 'batch_size': 1, 'is_train': False}
# INFO:tensorflow:Restoring parameters from /home/trex/handwriting-generation/models/unconditional-stroke-model/-91500

# %% [markdown]
# ### Conditional generation:

# %%
stroke = generate_conditionally(
    text='baruch tabanpour', random_seed=10,
    std_bias=2)
plot_stroke(stroke)
# Out:
# Loading:  {'save_path': '/home/trex/handwriting-generation/models/conditional-stroke-model', 'learning_rate': 0.0001, 'mixture_components': 20, 'vocab_size': 60, 'char_dict': {' ': 0, '<UNK>': 1, ',': 2, 'L': 3, 'e': 4, 'h': 5, 'C': 6, 'k': 7, 'U': 8, 'b': 9, 'f': 10, 'N': 11, 'Q': 12, 'I': 13, 'r': 14, 'O': 15, 'y': 16, 'Y': 17, '?': 18, 'D': 19, 'V': 20, 'B': 21, '-': 22, 'w': 23, 'S': 24, 'W': 25, '"': 26, 'X': 27, "'": 28, 'P': 29, 'R': 30, 'q': 31, 'x': 32, 's': 33, 'd': 34, 't': 35, '.': 36, 'j': 37, 'E': 38, 'H': 39, 'J': 40, 'l': 41, 'F': 42, 'K': 43, 'o': 44, 'T': 45, 'Z': 46, 'A': 47, 'n': 48, 'a': 49, 'g': 50, 'm': 51, 'G': 52, 'v': 53, 'u': 54, 'c': 55, 'i': 56, 'p': 57, 'M': 58, 'z': 59}, 'window_components': 10, 'window_output_dim': 30, 'char_seq_len': 17, 'num_layers': 3, 'hidden_size': 200, 'dropout': 0.15, 'max_grad_norm': 10, 'decay': 0.95, 'momentum': 0.9, 'rnn_steps': 1, 'batch_size': 1, 'is_train': False}
# INFO:tensorflow:Restoring parameters from /home/trex/handwriting-generation/models/conditional-stroke-model/-17978

# %% [markdown]
# ### Handwriting recognition:
#
# NA
